# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonlightO2/Road-Accident-Data-Analysis-Project/blob/main/Road_Accident_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Road Accident Data Analysis**
# Article: https://medium.com/@mercymallel1/road-accidents-data-analysis-project-2d4fd1c9f429
#
# Dataset: https://drive.google.com/file/d/1R_uaoZL18nRbqC_MULVne90h3SdRbAyn/view
#
# From the analysis of the dataset, we can conclude that:
#
# 1. Casualties in the year 2021 were lower than in the tear 2020 across all months.
#
# 2. Car causes the highest number of casualties,79.8% of the total
# casualties, followed by motorcycle while the agricultural vehicle causes the least number of casualties.
#
# 3. Single carriageway causes the highest number of casualties, 74.45% of the total casualties, while slip road had the least number of casualties.
#
# 4. Dry surface has the highest number of casualties,66.9%, followed by wet surface, 27.6%, then snow / ice surface, 5.5%, having the least number of casualties.
#
# 5. 38.77% of all the casualties happen in the rural areas while 61.23% of all casualties happen in the urban areas.
#
# 6. 72.98% of all casualties happens when the area is lit, either during the daylight or if its dark but the lights are lit, while 27.07% of all casualties happens when its dark.
#
# 7. 76.7% of all casualties / accidents happens during the day and 23.3% of all casualties / accidents happens at night.

# %%
import pandas as pd
import numpy as np
import folium
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import IFrame

# %%
# Load the dataset
df = pd.read_csv('Road Accidents.csv', error_bad_lines=False)
# Out:
# <ipython-input-74-d4fd12ac44ea>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('Road Accidents.csv', error_bad_lines=False)
# Skipping line 9114: expected 21 fields, saw 35
# Skipping line 18392: expected 21 fields, saw 25
#
# <ipython-input-74-d4fd12ac44ea>:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Road Accidents.csv', error_bad_lines=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317248 entries, 0 to 317247
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              317248 non-null  object
#  1   Accident Date               317248 non-null  object
#  2   Day_of_Week                 317248 non-null  object
#  3   Junction_Control            317248 non-null  object
#  4   Junction_Detail             317248 non-null  object
#  5   Accident_Severity           317248 non-null  object
#  6   Latitude                    317248 non-null  float64
#  7   Light_Conditions            317248 non-null  object
#  8   Local_Authority_(District)  317248 non-null  object
#  9   Carriageway_Hazards         317245 non-null  object
#  10  Longitude                   317248 non-null  float64
#  11  Number_of_Casualties        317248 non-null  int64
#  12  Number_of_Vehicles          317248 non-null  int64
#  13  Police_Force                317248 non-null  object
#  14  Road_Surface_Conditions     316931 non-null  object
#  15  Road_Type                   315675 non-null  object
#  16  Speed_limit                 317248 non-null  object
#  17  Time                        317231 non-null  object
#  18  Urban_or_Rural_Area         317247 non-null  object
#  19  Weather_Conditions          311097 non-null  object
#  20  Vehicle_Type                317247 non-null  object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 50.8+ MB

# %%
df.columns.tolist()
# Out:
# ['Accident_Index',
#  'Accident Date',
#  'Day_of_Week',
#  'Junction_Control',
#  'Junction_Detail',
#  'Accident_Severity',
#  'Latitude',
#  'Light_Conditions',
#  'Local_Authority_(District)',
#  'Carriageway_Hazards',
#  'Longitude',
#  'Number_of_Casualties',
#  'Number_of_Vehicles',
#  'Police_Force',
#  'Road_Surface_Conditions',
#  'Road_Type',
#  'Speed_limit',
#  'Time',
#  'Urban_or_Rural_Area',
#  'Weather_Conditions',
#  'Vehicle_Type']

# %%
# Define a dictionary for mapping old column names to new column names
column_name_mapping = {
    'Accident_Index': 'Accident Index',
    'Accident Date': 'Accident Date',
    'Day_of_Week': 'Day of Week',
    'Junction_Control': 'Junction Control',
    'Junction_Detail': 'Junction Detail',
    'Accident_Severity': 'Accident Severity',
    'Latitude': 'Latitude',
    'Light_Conditions': 'Light Conditions',
    'Local_Authority_(District)': 'Local Authority (District)',
    'Carriageway_Hazards': 'Carriageway Hazards',
    'Longitude': 'Longitude',
    'Number_of_Casualties': 'Number of Casualties',
    'Number_of_Vehicles': 'Number of Vehicles',
    'Police_Force': 'Police Force',
    'Road_Surface_Conditions': 'Road Surface Conditions',
    'Road_Type': 'Road Type',
    'Speed_limit': 'Speed limit',
    'Time': 'Time',
    'Urban_or_Rural_Area': 'Urban or Rural Area',
    'Weather_Conditions': 'Weather Conditions',
    'Vehicle_Type': 'Vehicle Type'
}

# Rename the columns using the mapping dictionary
df = df.rename(columns=column_name_mapping)

# %%
# Now df contains the DataFrame with the updated column names
# You can save it back to a CSV file or continue with your analysis
# For example:
df.to_csv('Road Accidents Dataset.csv', index=False)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Accident Index Accident Date Day of Week              Junction Control  \
# 0       200901BS70001    2021-01-01    Thursday      Give way or uncontrolled
# 1       200901BS70002    2021-01-05      Monday      Give way or uncontrolled
# 2       200901BS70003    2021-01-04      Sunday      Give way or uncontrolled
# 3       200901BS70004    2021-01-05      Monday           Auto traffic signal
# 4       200901BS70005    2021-01-06     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 317243  201091NM01760    2022-02-18    Thursday  Data missing or out of range
# 317244  201091NM01881    2022-02-21      Sunday  Data missing or out of range
# 317245  201091NM01935    2022-02-23     Tuesday      Give way or uncontrolled
# 317246  201091NM01964    2022-02-23     Tuesday      Give way or uncontrolled
# 317247  201091NM02142    2022-02-28      Sunday      Give way or uncontrolled
#
#                             Junction Detail Accident Severity   Latitude  \
# 0                   T or staggered junction           Serious  51.512273
# 1                                Crossroads           Serious  51.514399
# 2                   T or staggered junction            Slight  51.486668
# 3                   T or staggered junction           Serious  51.507804
# 4                                Crossroads           Serious  51.482076
# ...                                     ...               ...        ...
# 317243  Not at junction or within 20 metres            Slight  57.374005
# 317244  Not at junction or within 20 metres            Slight  57.232273
# 317245              T or staggered junction            Slight  57.585044
# 317246              T or staggered junction           Serious  57.214898
# 317247              T or staggered junction           Serious  57.575210
#
#               Light Conditions Local Authority (District)  \
# 0                     Daylight     Kensington and Chelsea
# 1                     Daylight     Kensington and Chelsea
# 2                     Daylight     Kensington and Chelsea
# 3                     Daylight     Kensington and Chelsea
# 4        Darkness - lights lit     Kensington and Chelsea
# ...                        ...                        ...
# 317243                Daylight                   Highland
# 317244  Darkness - no lighting                   Highland
# 317245                Daylight                   Highland
# 317246  Darkness - no lighting                   Highland
# 317247                Daylight                   Highland
#
#          Carriageway Hazards  ...  Number of Casualties  Number of Vehicles  \
# 0                       None  ...                     1                   2
# 1                       None  ...                    11                   2
# 2                       None  ...                     1                   2
# 3                       None  ...                     1                   2
# 4                       None  ...                     1                   2
# ...                      ...  ...                   ...                 ...
# 317243                  None  ...                     2                   1
# 317244                  None  ...                     1                   1
# 317245                  None  ...                     1                   3
# 317246                  None  ...                     1                   2
# 317247  Other object on road  ...                     1                   1
#
#                Police Force Road Surface Conditions           Road Type  \
# 0       Metropolitan Police                     Dry      One way street
# 1       Metropolitan Police             Wet or damp  Single carriageway
# 2       Metropolitan Police                     Dry  Single carriageway
# 3       Metropolitan Police            Frost or ice  Single carriageway
# 4       Metropolitan Police                     Dry  Single carriageway
# ...                     ...                     ...                 ...
# 317243             Northern                     Dry  Single carriageway
# 317244             Northern            Frost or ice  Single carriageway
# 317245             Northern            Frost or ice  Single carriageway
# 317246             Northern             Wet or damp  Single carriageway
# 317247             Northern             Wet or damp    Dual carriageway
#
#        Speed limit   Time Urban or Rural Area     Weather Conditions  \
# 0               30  15:11               Urban     Fine no high winds
# 1               30  10:59               Urban     Fine no high winds
# 2               30  14:19               Urban     Fine no high winds
# 3               30   8:10               Urban                  Other
# 4               30  17:25               Urban     Fine no high winds
# ...            ...    ...                 ...                    ...
# 317243          60   7:00               Rural     Fine no high winds
# 317244          60   3:00               Rural     Fine no high winds
# 317245          30   9:38               Rural     Fine no high winds
# 317246          60  18:25               Rural     Fine no high winds
# 317247          60  15:45               Rural  Snowing no high winds
#
#                  Vehicle Type
# 0                         Car
# 1       Taxi/Private hire car
# 2       Taxi/Private hire car
# 3       Motorcycle over 500cc
# 4                         Car
# ...                       ...
# 317243                    Car
# 317244                    Car
# 317245                    Car
# 317246  Motorcycle over 500cc
# 317247                    Car
#
# [317248 rows x 21 columns]>

# %%
df.head(2)
# Out:
#   Accident Index Accident Date Day of Week          Junction Control  \
# 0  200901BS70001    2021-01-01    Thursday  Give way or uncontrolled
# 1  200901BS70002    2021-01-05      Monday  Give way or uncontrolled
#
#            Junction Detail Accident Severity   Latitude Light Conditions  \
# 0  T or staggered junction           Serious  51.512273         Daylight
# 1               Crossroads           Serious  51.514399         Daylight
#
#   Local Authority (District) Carriageway Hazards  ...  Number of Casualties  \
# 0     Kensington and Chelsea                None  ...                     1
# 1     Kensington and Chelsea                None  ...                    11
#
#    Number of Vehicles         Police Force Road Surface Conditions  \
# 0                   2  Metropolitan Police                     Dry
# 1                   2  Metropolitan Police             Wet or damp
#
#             Road Type Speed limit   Time Urban or Rural Area  \
# 0      One way street          30  15:11               Urban
# 1  Single carriageway          30  10:59               Urban
#
#    Weather Conditions           Vehicle Type
# 0  Fine no high winds                    Car
# 1  Fine no high winds  Taxi/Private hire car
#
# [2 rows x 21 columns]

# %%
# Replace 'Fetal' with 'Fatal' in the 'Accident Severity' column
df['Accident Severity'] = df['Accident Severity'].replace('Fetal', 'Fatal')

# %%
# Iterate through each column and print unique values
for column in df.columns:
    unique_values = df[column].unique()
    print(f'Unique values for {column}:\n{unique_values}\n')
# Out:
# Unique values for Accident Index:
# ['200901BS70001' '200901BS70002' '200901BS70003' ... '201091NM01935'
#  '201091NM01964' '201091NM02142']
#
# Unique values for Accident Date:
# ['2021-01-01' '2021-01-05' '2021-01-04' '2021-01-06' '2021-01-08'
#  '2021-01-02' '2021-01-07' '2021-01-10' '2021-01-16' '2021-01-12'
#  '2021-01-09' '2021-01-17' '2021-01-25' '2021-01-26' '2021-01-19'
#  'Not at junction or within 20 metres' 'Roundabout' 'Mini-roundabout'
#  'More than 4 arms (not roundabout)' 'Private drive or entrance'
#  'Slip road' 'Other junction' 'T or staggeredon']
#
# Unique values for Accident Severity:
# ['Serious' 'Slight' 'Fatal']
#
# Unique values for Latitude:
# [51.512273 51.514399 51.486668 ... 57.585044 57.214898 57.57521 ]
#
# Unique values for Light Conditions:
# ['Daylight' 'Darkness - lights lit' 'Darkness - lighting unknown'
#  'Darkness - lights unlit' 'Darkness - no lighting']
#
# Unique values for Local Authority (District):
# ['Kensington and Chelsea' 'Hammersmith and Fulham' 'Westminster'
#  'Hounslow' 'City of London' 'Tower Hamlets' 'Hackney' 'Camden'
#  'Southwark' 'Brent' 'Haringey' 'Islington' 'Barnet' 'Ealing' 'Merton'
#  'Wandsworth' 'Lambeth' 'Richmond upon Thames' 'Hillingdon' 'Enfield'
#  'Croydon' 'Sutton' 'Bromley' 'Newham' 'London Airport (Heathrow)'
#  'Waltham Forest' 'Redbridge' 'Barking and Dagenham' 'Havering' 'Eden'
#  'Copeland' 'South Lakeland' 'Barrow-in-Furness' 'Allerdale' 'Carlisle'
#  'Fylde' 'Blackpool' 'Wyre' 'Lancaster' 'Chorley' 'West Lancashire'
#  'South Ribble' 'Preston' 'Lewisham' 'Greenwich' 'Bexley' 'Harrow'
#  'Kingston upon Thames' 'Blackburn with Darwen' 'Hyndburn' 'Ribble Valley'
#  'Burnley' 'Pendle' 'Rossendale' 'Wirral' 'Sefton' 'St. Helens'
#  'Liverpool' 'Knowsley' 'Manchester' 'Salford' 'Tameside' 'Stockport'
#  'Bolton' 'Wigan' 'Trafford' 'Bury' 'Rochdale' 'Oldham' 'Vale Royal'
#  'Crewe and Nantwich' 'Halton' 'Chester' 'Macclesfield' 'Cheshire East'
#  'Warrington' 'Crewe and ntwich' 'Cheshire West and Chester' 'Congleton'
#  'Ellesmere Port and Neston' 'Wansbeck' 'Blyth Valley' 'North Tyneside'
#  'Newcastle upon Tyne' 'Tynedale' 'Alnwick' 'South Tyneside' 'Gateshead'
#  'Castle Morpeth' 'Sunderland' 'Berwick-upon-Tweed' 'Northumberland'
#  'Durham' 'County Durham' 'Easington' 'Chester-le-Street' 'Derwentside'
#  'Wear Valley' 'Teesdale' 'Darlington' 'Sedgefield' 'Hambleton' 'York'
#  'Craven' 'Richmondshire' 'Scarborough' 'Selby' 'Harrogate' 'Ryedale'
#  'Calderdale' 'Bradford' 'Wakefield' 'Leeds' 'Kirklees' 'Doncaster'
#  'Rotherham' 'Barnsley' 'Sheffield' 'North East Lincolnshire'
#  'North Lincolnshire' 'East Riding of Yorkshire'
#  'Kingston upon Hull, City of' 'Hartlepool' 'Redcar and Cleveland'
#  'Middlesbrough' 'Stockton-on-Tees' 'Birmingham' 'Wolverhampton' 'Walsall'
#  'Dudley' 'Sandwell' 'Solihull' 'Coventry' 'Lichfield' 'Stafford'
#  'Stoke-on-Trent' 'East Staffordshire' 'Newcastle-under-Lyme'
#  'Cannock Chase' 'South Staffordshire' 'Tamworth'
#  'Staffordshire Moorlands' 'Wychavon' 'Malvern Hills' 'Worcester'
#  'Wyre Forest' 'Herefordshire, County of' 'Shropshire' 'Redditch'
#  'Bromsgrove' 'South Shropshire' 'North Shropshire'
#  'Shrewsbury and Atcham' 'Oswestry' 'Telford and Wrekin' 'Bridgnorth'
#  'Stratford-upon-Avon' 'Warwick' 'North Warwickshire' 'Rugby'
#  'Nuneaton and Bedworth' 'Amber Valley' 'Erewash' 'Bolsover'
#  'Derbyshire Dales' 'High Peak' 'Chesterfield' 'North East Derbyshire'
#  'Derby' 'South Derbyshire' 'Ashfield' 'Mansfield' 'Newark and Sherwood'
#  'Nottingham' 'Gedling' 'Bassetlaw' 'Broxtowe' 'Rushcliffe'
#  'South Kesteven' 'South Holland' 'North Kesteven' 'Lincoln'
#  'East Lindsey' 'Boston' 'West Lindsey' 'Leicester' 'Melton' 'Charnwood'
#  'Blaby' 'Harborough' 'Rutland' 'Hinckley and Bosworth'
#  'North West Leicestershire' 'Oadby and Wigston' 'Corby' 'Wellingborough'
#  'Daventry' 'Kettering' 'East Northamptonshire' 'Northampton'
#  'South Northamptonshire' 'South Cambridgeshire' 'Cambridge'
#  'Peterborough' 'East Cambridgeshire' 'Huntingdonshire' 'Fenland'
#  'Great Yarmouth' 'Norwich' 'Breckland' 'Broadland'
#  "King's Lynn and West Norfolk" 'South Norfolk' 'North Norfolk'
#  'Mid Suffolk' 'Suffolk Coastal' 'Forest Heath' 'St. Edmundsbury'
#  'Babergh' 'Ipswich' 'Waveney' 'Bedford' 'Mid Bedfordshire'
#  'Central Bedfordshire' 'South Bedfordshire' 'Luton' 'East Hertfordshire'
#  'Broxbourne' 'Welwyn Hatfield' 'North Hertfordshire' 'Watford'
#  'Three Rivers' 'Dacorum' 'Hertsmere' 'St. Albans' 'Stevege' 'Stevenage'
#  'Braintree' 'Chelmsford' 'Epping Forest' 'Maldon' 'Tendring' 'Basildon'
#  'Brentwood' 'Southend-on-Sea' 'Colchester' 'Uttlesford' 'Harlow'
#  'Thurrock' 'Castle Point' 'Rochford' 'Aylesbury Vale' 'Wycombe'
#  'South Bucks' 'Chiltern' 'Milton Keynes' 'South Oxfordshire' 'Slough'
#  'Cherwell' 'Oxford' 'Vale of White Horse' 'West Oxfordshire'
#  'West Berkshire' 'Windsor and Maidenhead' 'Bracknell Forest' 'Reading'
#  'Wokingham' 'Rushmoor' 'Basingstoke and Deane' 'Isle of Wight' 'Hart'
#  'Portsmouth' 'Fareham' 'Southampton' 'East Hampshire' 'Winchester'
#  'Gosport' 'New Forest' 'Eastleigh' 'Test Valley' 'Havant' 'Elmbridge'
#  'Mole Valley' 'Runnymede' 'Epsom and Ewell' 'Guildford' 'Spelthorne'
#  'Reigate and Banstead' 'Waverley' 'Surrey Heath' 'Woking' 'Tandridge'
#  'Medway' 'Dartford' 'Gravesham' 'Tonbridge and Malling' 'Canterbury'
#  'Thanet' 'Swale' 'Maidstone' 'Tunbridge Wells' 'Sevenoaks' 'Shepway'
#  'Ashford' 'Dover' 'Brighton and Hove' 'Worthing' 'Hastings' 'Horsham'
#  'Wealden' 'Lewes' 'Mid Sussex' 'Eastbourne' 'Crawley' 'Rother' 'Arun'
#  'Chichester' 'Adur' 'Cornwall' 'Kerrier' 'Penwith' 'North Cornwall'
#  'Caradon' 'Plymouth' 'Torbay' 'North Devon' 'Torridge' 'Exeter'
#  'South Hams' 'West Devon' 'Restormel' 'Carrick' 'Teignbridge'
#  'East Devon' 'Mid Devon' 'Mendip' 'South Gloucestershire'
#  'North Somerset' 'Sedgemoor' 'Taunton Deane' 'Bristol, City of'
#  'South Somerset' 'West Somerset' 'Bath and North East Somerset'
#  'Cotswold' 'Gloucester' 'Stroud' 'Tewkesbury' 'Cheltenham'
#  'Forest of Dean' 'Swindon' 'Wiltshire' 'West Wiltshire' 'Salisbury'
#  'Kennet' 'North Wiltshire' 'Bournemouth' 'West Dorset' 'Poole'
#  'East Dorset' 'Christchurch' 'Purbeck' 'North Dorset'
#  'Weymouth and Portland' 'Flintshire' 'Denbighshire' 'Wrexham' 'Conwy'
#  'Gwynedd' 'Isle of Anglesey' 'Caerphilly' 'Torfaen' 'Newport'
#  'Blaeu Gwent' 'Blaenau Gwent' 'Monmouthshire' 'Rhondda, Cynon, Taff'
#  'Merthyr Tydfil' 'Cardiff' 'The Vale of Glamorgan' 'Bridgend'
#  'Neath Port Talbot' 'Swansea' 'Carmarthenshire' 'Ceredigion'
#  'Pembrokeshire' 'Powys' 'Highland' 'Western Isles' 'Orkney Islands'
#  'Shetland Islands' 'Moray' 'Aberdeenshire' 'Aberdeen City' 'Angus'
#  'Perth and Kinross' 'Dundee City' 'Fife' 'Edinburgh, City of'
#  'East Lothian' 'Scottish Borders' 'West Lothian' 'Midlothian' 'Falkirk'
#  'Stirling' 'Clackmannshire' 'Clackmannanshire' 'Glasgow City'
#  'East Dunbartonshire' 'East Renfrewshire' 'Renfrewshire' 'Inverclyde'
#  'Argyll and Bute' 'West Dunbartonshire' 'North Lanarkshire'
#  'North Larkshire' 'South Lanarkshire' 'South Larkshire' 'North Ayrshire'
#  'East Ayrshire' 'South Ayrshire' 'Dumfries and Galloway']
#
# Unique values for Carriageway Hazards:
# ['None' 'Pedestrian in carriageway - not injured' 'Other object on road'
#  'Any animal in carriageway (except ridden horse)' 'Previous accident'
#  'Vehicle load on road' nan]
#
# Unique values for Longitude:
# [-0.201349 -0.199248 -0.179599 ... -3.862727 -3.823997 -3.895673]
#
# Unique values for Number of Casualties:
# [ 1 11  3  2  4  5  6 10  8  7  9 13 12 14 16 18 15 19 21 17 27 48 40 24
#  26 22 42 43]
#
# Unique values for Number of Vehicles:
# [ 2  1  3  4  5  9  6  8  7 10 16 13 14 11 12 32 19]
#
# Unique values for Police Force:
# ['Metropolitan Police' 'City of London' 'Cumbria' 'Lancashire'
#  'Merseyside' 'Greater Manchester' 'Cheshire' 'Northumbria' 'Durham'
#  'North Yorkshire' 'West Yorkshire' 'South Yorkshire' 'Humberside'
#  'Cleveland' 'West Midlands' 'Staffordshire' 'West Mercia' 'Warwickshire'
#  'Derbyshire' 'Nottinghamshire' 'Lincolnshire' 'Leicestershire'
#  'Northamptonshire' 'Cambridgeshire' 'Norfolk' 'Suffolk' 'Bedfordshire'
#  'Hertfordshire' 'Essex' 'Thames Valley' 'Hampshire' 'Surrey' 'Kent'
#  'Sussex' 'Devon and Cornwall' 'Avon and Somerset' 'Gloucestershire'
#  'Wiltshire' 'Dorset' 'North Wales' 'Gwent' 'South Wales' 'Dyfed-Powys'
#  'Northern' 'Grampian' 'Tayside' 'Fife' 'Lothian and Borders' 'Central'
#  'Strathclyde' 'Dumfries and Galloway']
#
# Unique values for Road Surface Conditions:
# ['Dry' 'Wet or damp' 'Frost or ice' 'Snow' 'Flood over 3cm. deep' nan]
#
# Unique values for Road Type:
# ['One way street' 'Single carriageway' 'Dual carriageway' 'Roundabout'
#  'Slip road' nan 'Single can']
#
# Unique values for Speed limit:
# ['30' '20' '50' '40' '70' '60' 'Fine no high winds' 60 30 70 40 50 20 10
#  15]
#
# Unique values for Time:
# ['15:11' '10:59' '14:19' ... '5:17' '2:52' nan]
#
# Unique values for Urban or Rural Area:
# ['Urban' 'Rural' nan]
#
# Unique values for Weather Conditions:
# ['Fine no high winds' 'Other' 'Raining no high winds'
#  'Snowing no high winds' 'Fine + high winds' 'Raining + high winds' nan
#  'Snowing + high winds' 'Fog or mist']
#
# Unique values for Vehicle Type:
# ['Car' 'Taxi/Private hire car' 'Motorcycle over 500cc'
#  'Van / Goods 3.5 tonnes mgw or under' 'Goods over 3.5t. and under 7.5t'
#  'Motorcycle 125cc and under' 'Motorcycle 50cc and under'
#  'Bus or coach (17 or more pass seats)' 'Goods 7.5 tonnes mgw and over'
#  'Other vehicle' 'Motorcycle over 125cc and up to 500cc'
#  'Agricultural vehicle' 'Minibus (8 - 16 passenger seats)' 'Pedal cycle'
#  nan 'Ridden horse']

# %%
# Iterate through each column and print the number of unique values
for column in df.columns:
    num_unique_values = df[column].nunique()
    print(f'Number of unique values for {column}: {num_unique_values}')
# Out:
# Number of unique values for Accident Index: 197644
# Number of unique values for Accident Date: 730
# Number of unique values for Day of Week: 7
# Number of unique values for Junction Control: 7
# Number of unique values for Junction Detail: 10
# Number of unique values for Accident Severity: 3
# Number of unique values for Latitude: 264362
# Number of unique values for Light Conditions: 5
# Number of unique values for Local Authority (District): 422
# Number of unique values for Carriageway Hazards: 6
# Number of unique values for Longitude: 269856
# Number of unique values for Number of Casualties: 28
# Number of unique values for Number of Vehicles: 17
# Number of unique values for Police Force: 51
# Number of unique values for Road Surface Conditions: 5
# Number of unique values for Road Type: 6
# Number of unique values for Speed limit: 15
# Number of unique values for Time: 1440
# Number of unique values for Urban or Rural Area: 2
# Number of unique values for Weather Conditions: 8
# Number of unique values for Vehicle Type: 15

# %%
# Create a DataFrame with column names and their corresponding number of unique values
unique_counts = pd.DataFrame({
    'Column': df.columns,
    'Number of Unique Values': [df[column].nunique() for column in df.columns]
})

# Sort the DataFrame by the number of unique values in descending order
unique_counts_sorted = unique_counts.sort_values(by='Number of Unique Values', ascending=False)

# Print the sorted DataFrame
print(unique_counts_sorted)
# Out:
#                         Column  Number of Unique Values
# 10                   Longitude                   269856
# 6                     Latitude                   264362
# 0               Accident Index                   197644
# 17                        Time                     1440
# 1                Accident Date                      730
# 8   Local Authority (District)                      422
# 13                Police Force                       51
# 11        Number of Casualties                       28
# 12          Number of Vehicles                       17
# 16                 Speed limit                       15
# 20                Vehicle Type                       15
# 4              Junction Detail                       10
# 19          Weather Conditions                        8
# 2                  Day of Week                        7
# 3             Junction Control                        7
# 9          Carriageway Hazards                        6
# 15                   Road Type                        6
# 7             Light Conditions                        5
# 14     Road Surface Conditions                        5
# 5            Accident Severity                        3
# 18         Urban or Rural Area                        2

# %% [markdown]
# ## **1. Histogram for 'Number of Casualties'**

# %%
# Plot a histogram for 'Number of Casualties'
plt.figure(figsize=(10, 6))
plt.hist(df['Number of Casualties'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Number of Casualties')
plt.xlabel('Number of Casualties')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **2. Bar Chart for 'Accident Severity'**

# %%
# Plot a bar chart for 'Accident Severity'
plt.figure(figsize=(10, 6))
sns.countplot(x='Accident Severity', data=df, palette='viridis')
plt.title('Distribution of Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **3. Scatter Plot for 'Latitude' and 'Longitude'**

# %%
# Plot a scatter plot for 'Latitude' and 'Longitude'
plt.figure(figsize=(10, 8))
plt.scatter(df['Longitude'], df['Latitude'], alpha=0.5, c='red', edgecolors='w', s=20)
plt.title('Scatter Plot of Latitude and Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## **4. Boxplot for 'Number of Vehicles' by 'Accident Severity'**

# %%
# Plot a boxplot for 'Number of Vehicles' by 'Accident Severity'
plt.figure(figsize=(12, 8))
sns.boxplot(x='Accident Severity', y='Number of Vehicles', data=df, palette='Set2')
plt.title('Boxplot of Number of Vehicles by Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Vehicles')
plt.show()

# %% [markdown]
# ## **5. Countplot for 'Day of Week'**

# %%
# Plot a countplot for 'Day of Week'
plt.figure(figsize=(10, 6))
sns.countplot(x='Day of Week', data=df, palette='pastel')
plt.title('Distribution of Accidents by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **6. Pie Chart based on Accident Severity**

# %%
# Plot a pie chart for the distribution of Accident Severity
severity_counts = df['Accident Severity'].value_counts()
labels = severity_counts.index
values = severity_counts.values

plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'gold', 'lightskyblue'])
plt.title('Distribution of Accident Severity')
plt.show()

# %% [markdown]
# ## **7. Accidents vs Type of Vehicle**

# %%
# Plot a bar chart for accidents based on the type of vehicle
plt.figure(figsize=(12, 8))
sns.countplot(x='Vehicle Type', data=df, palette='Set3', order=df['Vehicle Type'].value_counts().index)
plt.title('Distribution of Accidents based on Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## **8. Accidents vs Road Type**

# %%
# Plot a bar chart for accidents based on road type
plt.figure(figsize=(12, 8))
sns.countplot(x='Road Type', data=df, palette='viridis', order=df['Road Type'].value_counts().index)
plt.title('Distribution of Accidents based on Road Type')
plt.xlabel('Road Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## **9. Accidents vs Road Surface**

# %%
# Plot a bar chart for accidents based on road surface conditions
plt.figure(figsize=(12, 8))
sns.countplot(x='Road Surface Conditions', data=df, palette='coolwarm', order=df['Road Surface Conditions'].value_counts().index)
plt.title('Distribution of Accidents based on Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## **10. Location (Rural or Urban)**

# %%
# Plot a bar chart for accidents based on location (rural or urban)
plt.figure(figsize=(8, 6))
sns.countplot(x='Urban or Rural Area', data=df, palette='Set2')
plt.title('Distribution of Accidents based on Location')
plt.xlabel('Urban or Rural Area')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# ## **11. Light Conditions (Dark vs Daylight)**

# %%
# Plot a bar chart for accidents based on light conditions (dark vs daylight)
plt.figure(figsize=(8, 6))
sns.countplot(x='Light Conditions', data=df, palette='husl', order=['Daylight', 'Darkness - Lights lit', 'Darkness - Lights unlit'])
plt.title('Distribution of Accidents based on Light Conditions')
plt.xlabel('Light Conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## **12. 2021 vs 2022 Casualties monthly trend**

# %%
# Convert 'Accident Date' to datetime
df['Accident Date'] = pd.to_datetime(df['Accident Date'])

# Extract year and month information
df['Year'] = df['Accident Date'].dt.year
df['Month'] = df['Accident Date'].dt.month

# Filter data for the years 2021 and 2022
df_2021_2022 = df[df['Year'].isin([2021, 2022])]

# Plot the monthly trend of casualties for 2021 and 2022
plt.figure(figsize=(12, 8))
sns.lineplot(x='Month', y='Number of Casualties', hue='Year', data=df_2021_2022, ci=None, marker='o')
plt.title('Monthly Trend of Casualties (2021 vs 2022)')
plt.xlabel('Month')
plt.ylabel('Number of Casualties')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
plt.show()
# Out:
# <ipython-input-96-6a30ddb62b95>:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Month', y='Number of Casualties', hue='Year', data=df_2021_2022, ci=None, marker='o')

# %% [markdown]
# ## **13. Time of Day / Night**

# %%
# Clean the 'Time' column by dropping rows with invalid values
df = df.dropna(subset=['Time'])
df = df[df['Time'].str.contains(':')]  # Assuming valid times contain a colon

# Extract the hour information from the 'Time' column
df['Hour'] = pd.to_datetime(df['Time'], errors='coerce').dt.hour

# Drop rows with NaN values in the 'Hour' column (resulting from invalid time values)
df = df.dropna(subset=['Hour'])

# Categorize the hours into 'Day' and 'Night' based on a threshold
threshold = 6  # 6 AM
df['Day or Night'] = df['Hour'].apply(lambda x: 'Day' if 6 <= x < 18 else 'Night')

# Plot a bar chart for accidents based on time of day
plt.figure(figsize=(8, 6))
sns.countplot(x='Day or Night', data=df, palette='muted')
plt.title('Distribution of Accidents based on Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# ## **14. Accidents Map**

# %%
import folium
from IPython.display import IFrame, display

# Create a folium map centered at the mean of Latitude and Longitude
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=10)

# Add markers for each location in the DataFrame
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Accident Index']).add_to(my_map)

# Save the map as an HTML file
html_file_path = '/content/Maps/Accidents_map.html'
my_map.save(html_file_path)

# Display the map in the Colab notebook using display module
display(IFrame(src=html_file_path, width=700, height=600))
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="/content/Maps/Accidents_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
